# %%
import json
import pandas

# %%
with open("masterchef_us.json") as file:
    data = json.load(file)
data
# Out:
# [{'season': 1,
#   'name': 'Whitney Miller',
#   'age': 22,
#   'home': 'Poplarville, Mississippi',
#   'occupation': 'College Student',
#   'evaluations': ['limegreen-WIN',
#    'white-IN',
#    'mistyrose-PT',
#    'cornflowerblue-HIGH',
#    'white-IN',
#    'mistyrose-PT',
#    'white-IN',
#    'orange-LOW',
#    '#959ffd-WIN',
#    'cornflowerblue-HIGH',
#    'limegreen-WIN',
#    'orange-LOW',
#    'limegreen-WIN',
#    'yellow-IMM',
#    'limegreen-WIN',
#    'gold-WINNER']},
#  {'season': 1,
#   'name': 'David Miller',
#   'age': 29,
#   'home': 'Boston, Massachusetts',
#   'occupation': 'Software Engineer',
#   'evaluations': ['white-IN',
#    'white-IN',
#    'mistyrose-PT',
#    'white-IN',
#    'white-IN',
#    '#959ffd-WIN',
#    'white-IN',
#    'white-IN',
#    '#959ffd-WIN',
#    'white-IN',
#    'white-IN',
#    'limegreen-WIN',
#    'yellow-IMM',
#    'limegreen-WIN',
#    'yellow-IMM',
#    'silver-RUNNER-UP']},
#  {'season': 1,
#   'name': 'Lee Knaz',
# ...
